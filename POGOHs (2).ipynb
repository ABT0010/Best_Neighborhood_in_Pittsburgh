# %% [markdown]
# # POGOH Station Location

# %% [markdown]
# Here we imported necessary libraries, which reads the CSV file of station locations into a pandas DataFrame. It then defines a helper function, latlon_to_neighborhood, which uses fp.geo_to_neighborhood to map each station’s geographic coordinates to a Pittsburgh neighborhood. This function is applied across all rows of the dataset, creating a new Neighborhood column. Finally, the code displays the first 60 rows so the updated dataset—with neighborhood labels—can be reviewed.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import fpsnippets as fp

# Load your pogo station dataset
pogoh_data = pd.read_csv("pogoh-station-locations-october-2025.csv")

# Define converter function
def latlon_to_neighborhood(row):
    return fp.geo_to_neighborhood(row['Latitude'], row['Longitude'])

# Apply conversion to each row
pogoh_data['Neighborhood'] = pogoh_data.apply(latlon_to_neighborhood, axis=1)

# Show first rows
pogoh_data.head(60)
# Out:
#     Id                                      Name  Total Docks   Latitude  \
# 0    1                  Pierce St & Summerlea St           19  40.456507
# 1    2       Eliza Furnace Trail & Swineburne St           15  40.425800
# 2    3                   Centre Ave & Addison St           15  40.444600
# 3    4         Burns White Center at 3 Crossings           15  40.456400
# 4    5                         Allegheny Station           19  40.448301
# 5    6                        10th St & Penn Ave           15  40.444653
# 6    7                    Liberty Ave & Gross St           15  40.459588
# 7    8                                Glasshouse           15  40.432900
# 8    9               South Side Trail & S 4th St           15  40.431336
# 9   10                   Zulema St & Coltart Ave           19  40.436055
# 10  11              Ellsworth Ave & N Neville St           15  40.448203
# 11  12              O'Hara St & University Place           23  40.445117
# 12  13                S Bouquet Ave & Sennott St           23  40.441638
# 13  14                 Tioga St & N Homewood Ave           15  40.454226
# 14  15                        Ivy St & Walnut St           19  40.451781
# 15  16      Penn Ave & Putnam St (Bakery Square)           19  40.455900
# 16  17                   Taylor St & Liberty Ave           15  40.462778
# 17  18                        21st St & Penn Ave           19  40.451800
# 18  19                       42nd St & Butler St           15  40.470221
# 19  20    Boulevard of the Allies & Parkview Ave           23  40.434400
# 20  21                  Liberty Ave & Stanwix St           15  40.441200
# 21  22                Forbes Ave & Market Square           19  40.440773
# 22  23  North Shore Trail & Fort Duquesne Bridge           23  40.445800
# 23  24                        Penn Ave & 33rd St           11  40.462000
# 24  25                 Penn Ave & S Whitfield St           15  40.461600
# 25  26  S 27th St & Sidney St. (Southside Works)           23  40.427991
# 26  27      W Station Square Dr & Bessemer Court           15  40.433800
# 27  28                  Fifth Ave & S Bouquet St           23  40.442200
# 28  29             Filmore St & S Bellefield Ave           27  40.445145
# 29  30                 Shady Ave & Ellsworth Ave           15  40.459181
# 30  31                          First Ave & B St           15  40.435922
# 31  32                      Ross St & Fourth Ave           15  40.437701
# 32  33             Schenley Dr & Schenley Dr Ext           19  40.442371
# 33  34               N Dithridge St & Centre Ave           19  40.451281
# 34  35                       Butler St & 36th St           15  40.465264
# 35  36                  Penn Ave & S Pacific Ave           15  40.464600
# 36  37                 S Negley Ave & Centre Ave           15  40.457316
# 37  38                Allequippa St & Darragh St           23  40.443591
# 38  39                   S 12th St & E Carson St           19  40.428600
# 39  40                         Penn Ave & 7th St           19  40.443310
# 40  41                     S 22nd St & Sidney St           19  40.429212
# 41  42                  Second Ave & Tecumseh St           19  40.408857
# 42  43                       Eliza St & Lytle St           15  40.413481
# 43  44                  Hamilton Ave & Fifth Ave           15  40.457570
# 44  45             N Braddock Ave & Hamilton Ave           15  40.453010
# 45  46               Bennett St & N Homewood Ave           15  40.456622
# 46  47                        17th St & Penn Ave           19  40.449626
# 47  48               Centre Ave & S Millvale Ave           19  40.453211
# 48  49                  Technology Dr & Bates St           23  40.430513
# 49  50                      Atwood St & Bates St           19  40.437987
# 50  51                  Coltart Ave & Forbes Ave           18  40.439012
# 51  52                   Bedford Ave & Memory Ln           19  40.448361
# 52  53                   Centre Ave & Heldman St           19  40.442841
# 53  54                   W Ohio St & Brighton Rd           19  40.452467
# 54  55            Brighton Rd & Pennsylvania Ave           19  40.456402
# 55  56                  Rosetta St & N Aiken Ave           15  40.467018
# 56  57                       52nd St & Butler St           19  40.480283
# 57  58                  W North Ave & Federal St           19  40.455268
# 58  59       Forbes Ave at TCS Hall (CMU Campus)           19  40.444654
# 59  60                   Wilkinsburg Park & Ride           19  40.446908
#
#     Longitude               Neighborhood
# 0  -79.932331                  Shadyside
# 1  -79.953400                  Hazelwood
# 2  -79.978300                Middle Hill
# 3  -79.980000             Strip District
# 4  -80.018007                    Chateau
# 5  -79.996074  Central Business District
# 6  -79.945204                 Bloomfield
# 7  -80.003000                South Shore
# 8  -79.995106           South Side Flats
# 9  -79.956827            Central Oakland
# 10 -79.947507                  Shadyside
# 11 -79.957118              North Oakland
# 12 -79.955764            Central Oakland
# 13 -79.897544             Homewood South
# 14 -79.932253                  Shadyside
# 15 -79.915300                  Shadyside
# 16 -79.950868                 Bloomfield
# 17 -79.983300             Strip District
# 18 -79.960380      Central Lawrenceville
# 19 -79.951900            Central Oakland
# 20 -80.004800  Central Business District
# 21 -80.003312  Central Business District
# 22 -80.009100                North Shore
# 23 -79.968300        Lower Lawrenceville
# 24 -79.925700               East Liberty
# 25 -79.966296           South Side Flats
# 26 -80.004700                South Shore
# 27 -79.957600            Central Oakland
# 28 -79.951083              North Oakland
# 29 -79.921996                  Shadyside
# 30 -79.997551  Central Business District
# 31 -79.996481  Central Business District
# 32 -79.951688            Central Oakland
# 33 -79.952982              North Oakland
# 34 -79.965652        Lower Lawrenceville
# 35 -79.939900                   Garfield
# 36 -79.934331                 Friendship
# 37 -79.965456            Terrace Village
# 38 -79.986371           South Side Flats
# 39 -79.999996  Central Business District
# 40 -79.974535           South Side Flats
# 41 -79.943684                  Hazelwood
# 42 -79.948254                  Hazelwood
# 43 -79.909952                    Larimer
# 44 -79.891204             Homewood South
# 45 -79.897503             Homewood South
# 46 -79.985918             Strip District
# 47 -79.947761                 Bloomfield
# 48 -79.959989              South Oakland
# 49 -79.953705            Central Oakland
# 50 -79.960292            Central Oakland
# 51 -79.978268          Bedford Dwellings
# 52 -79.981616           Crawford-Roberts
# 53 -80.013872           Allegheny Center
# 54 -80.015393          Central Northside
# 55 -79.935232                   Garfield
# 56 -79.954287        Upper Lawrenceville
# 57 -80.007123           Allegheny Center
# 58 -79.947535              North Oakland
# 59 -79.888645                       None

# %%
pogoh_counts = pogoh_data['Neighborhood'].value_counts()

# Convert to DataFrame and rename the column
pogoh_counts_df = pogoh_counts.rename_axis('Neighborhood').reset_index(name='Number of Pogoh Stations')

pogoh_counts_df
# Out:
#                  Neighborhood  Number of Pogoh Stations
# 0             Central Oakland                         7
# 1   Central Business District                         6
# 2                   Shadyside                         5
# 3            South Side Flats                         4
# 4               North Oakland                         4
# 5                   Hazelwood                         3
# 6                  Bloomfield                         3
# 7              Strip District                         3
# 8              Homewood South                         3
# 9                 South Shore                         2
# 10           Allegheny Center                         2
# 11        Lower Lawrenceville                         2
# 12                   Garfield                         2
# 13                    Chateau                         1
# 14                Middle Hill                         1
# 15                North Shore                         1
# 16               East Liberty                         1
# 17      Central Lawrenceville                         1
# 18                 Friendship                         1
# 19            Terrace Village                         1
# 20              South Oakland                         1
# 21                    Larimer                         1
# 22          Bedford Dwellings                         1
# 23           Crawford-Roberts                         1
# 24          Central Northside                         1
# 25        Upper Lawrenceville                         1

# %% [markdown]
# After grouping the number of POGOH bike stations per neighborhood, we find the total number of bike docks per neighborhood by counting every dock in specific stations located in the neighborhood.

# %%
dock_counts_df = (
    pogoh_data.groupby("Neighborhood")["Total Docks"]
             .sum()
             .rename("Total Number of Docks")
             .reset_index()
)

dock_counts_df.sort_values(by=['Total Number of Docks'], ascending=False).style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_67911">
#   <thead>
#     <tr>
#       <th id="T_67911_level0_col0" class="col_heading level0 col0" >Neighborhood</th>
#       <th id="T_67911_level0_col1" class="col_heading level0 col1" >Total Number of Docks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67911_row0_col0" class="data row0 col0" >Central Oakland</td>
#       <td id="T_67911_row0_col1" class="data row0 col1" >144</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row1_col0" class="data row1 col0" >Central Business District</td>
#       <td id="T_67911_row1_col1" class="data row1 col1" >98</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row2_col0" class="data row2 col0" >North Oakland</td>
#       <td id="T_67911_row2_col1" class="data row2 col1" >88</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row3_col0" class="data row3 col0" >Shadyside</td>
#       <td id="T_67911_row3_col1" class="data row3 col1" >87</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row4_col0" class="data row4 col0" >South Side Flats</td>
#       <td id="T_67911_row4_col1" class="data row4 col1" >76</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row5_col0" class="data row5 col0" >Strip District</td>
#       <td id="T_67911_row5_col1" class="data row5 col1" >53</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row6_col0" class="data row6 col0" >Bloomfield</td>
#       <td id="T_67911_row6_col1" class="data row6 col1" >49</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row7_col0" class="data row7 col0" >Hazelwood</td>
#       <td id="T_67911_row7_col1" class="data row7 col1" >49</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row8_col0" class="data row8 col0" >Homewood South</td>
#       <td id="T_67911_row8_col1" class="data row8 col1" >45</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row9_col0" class="data row9 col0" >Allegheny Center</td>
#       <td id="T_67911_row9_col1" class="data row9 col1" >38</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row10_col0" class="data row10 col0" >South Shore</td>
#       <td id="T_67911_row10_col1" class="data row10 col1" >30</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row11_col0" class="data row11 col0" >Garfield</td>
#       <td id="T_67911_row11_col1" class="data row11 col1" >30</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row12_col0" class="data row12 col0" >Lower Lawrenceville</td>
#       <td id="T_67911_row12_col1" class="data row12 col1" >26</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row13_col0" class="data row13 col0" >South Oakland</td>
#       <td id="T_67911_row13_col1" class="data row13 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row14_col0" class="data row14 col0" >Terrace Village</td>
#       <td id="T_67911_row14_col1" class="data row14 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row15_col0" class="data row15 col0" >North Shore</td>
#       <td id="T_67911_row15_col1" class="data row15 col1" >23</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row16_col0" class="data row16 col0" >Central Northside</td>
#       <td id="T_67911_row16_col1" class="data row16 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row17_col0" class="data row17 col0" >Bedford Dwellings</td>
#       <td id="T_67911_row17_col1" class="data row17 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row18_col0" class="data row18 col0" >Upper Lawrenceville</td>
#       <td id="T_67911_row18_col1" class="data row18 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row19_col0" class="data row19 col0" >Crawford-Roberts</td>
#       <td id="T_67911_row19_col1" class="data row19 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row20_col0" class="data row20 col0" >Chateau</td>
#       <td id="T_67911_row20_col1" class="data row20 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row21_col0" class="data row21 col0" >Central Lawrenceville</td>
#       <td id="T_67911_row21_col1" class="data row21 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row22_col0" class="data row22 col0" >East Liberty</td>
#       <td id="T_67911_row22_col1" class="data row22 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row23_col0" class="data row23 col0" >Middle Hill</td>
#       <td id="T_67911_row23_col1" class="data row23 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row24_col0" class="data row24 col0" >Friendship</td>
#       <td id="T_67911_row24_col1" class="data row24 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_67911_row25_col0" class="data row25 col0" >Larimer</td>
#       <td id="T_67911_row25_col1" class="data row25 col1" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
import folium
import pandas as pd
from folium.plugins import HeatMap

# Create base map centered on Pittsburgh
m = folium.Map(location=[40.4406, -79.9959], zoom_start=13)
pogoh_data = pd.read_csv("pogoh-station-locations-october-2025.csv")

# Clean the dataset to remove missing lat/lon/dock values
df_clean = pogoh_data[['Latitude', 'Longitude', 'Total Docks']].dropna()

# Prepare weighted heatmap data
heat_data = df_clean[['Latitude', 'Longitude', 'Total Docks']].values.tolist()

# Add HeatMap layer
HeatMap(
    heat_data,
    radius=25,
    blur=15,
    max_zoom=1
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cab4c934b1e57c91b9bcc5b78dd3135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cab4c934b1e57c91b9bcc5b78dd3135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cab4c934b1e57c91b9bcc5b78dd3135 = L.map(
#                 &quot;map_1cab4c934b1e57c91b9bcc5b78dd3135&quot;,
#                 {
#                     center: [40.4406, -79.9959],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f2aafbfa8adc3c110cd5ef84c949099 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f2aafbfa8adc3c110cd5ef84c949099.addTo(map_1cab4c934b1e57c91b9bcc5b78dd3135);
#
#
#             var heat_map_e239121af2ba914a66debea73df09d6e = L.heatLayer(
#                 [[40.45650668, -79.93233059, 19.0], [40.4258, -79.9534, 15.0], [40.4446, -79.9783, 15.0], [40.4564, -79.98, 15.0], [40.448301, -80.018007, 19.0], [40.4446526, -79.9960739, 15.0], [40.4595877, -79.9452035, 15.0], [40.4329, -80.003, 15.0], [40.431336, -79.995106, 15.0], [40.436055, -79.956827, 19.0], [40.448203, -79.947507, 15.0], [40.445117, -79.957118, 23.0], [40.441638, -79.955764, 23.0], [40.45422639, -79.89754441, 15.0], [40.451781, -79.932253, 19.0], [40.4559, -79.9153, 19.0], [40.462778, -79.950868, 15.0], [40.4518, -79.9833, 19.0], [40.470221, -79.96038, 15.0], [40.4344, -79.9519, 23.0], [40.4412, -80.0048, 15.0], [40.4407732, -80.0033121, 19.0], [40.4458, -80.0091, 23.0], [40.462, -79.9683, 11.0], [40.4616, -79.9257, 15.0], [40.4279908, -79.9662964, 23.0], [40.4338, -80.0047, 15.0], [40.4422, -79.9576, 23.0], [40.4451453, -79.95108339, 27.0], [40.4591811, -79.9219961, 15.0], [40.435922, -79.997551, 15.0], [40.43770062, -79.99648068, 15.0], [40.4423713, -79.9516881, 19.0], [40.451281, -79.952982, 19.0], [40.4652642, -79.965652, 15.0], [40.4646, -79.9399, 15.0], [40.4573163, -79.9343309, 15.0], [40.443591, -79.965456, 23.0], [40.4285997, -79.98637115, 19.0], [40.44331017, -79.99999588, 19.0], [40.42921222, -79.97453456, 19.0], [40.40885729, -79.94368379, 19.0], [40.41348098, -79.94825428, 15.0], [40.45756979, -79.90995233, 15.0], [40.45301036, -79.89120369, 15.0], [40.45662202, -79.8975032, 15.0], [40.44962631, -79.98591786, 19.0], [40.453211, -79.947761, 19.0], [40.43051278, -79.95998894, 23.0], [40.43798695, -79.95370453, 19.0], [40.43901176, -79.96029203, 18.0], [40.44836081, -79.9782682, 19.0], [40.44284135, -79.98161559, 19.0], [40.45246745, -80.01387184, 19.0], [40.45640241, -80.01539265, 19.0], [40.4670183, -79.93523215, 15.0], [40.48028273, -79.95428657, 19.0], [40.45526766, -80.0071234, 19.0], [40.44465401, -79.94753545, 19.0], [40.44690751, -79.88864487, 19.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_e239121af2ba914a66debea73df09d6e.addTo(map_1cab4c934b1e57c91b9bcc5b78dd3135);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stations_per_neighborhood = (
    pogoh_data['Neighborhood']
    .value_counts()
    .rename_axis('Neighborhood')
    .reset_index(name='Number of Stations')
)
docks_per_neighborhood = (
    pogoh_data.groupby('Neighborhood')['Total Docks']
    .sum()
    .reset_index(name='Total Docks')
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighborhood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 stations_per_neighborhood = (
# ----> 2     pogoh_data['Neighborhood']
#       3     .value_counts()
#       4     .rename_axis('Neighborhood')
#       5     .reset_index(name='Number of Stations')
#       6 )
#       7 docks_per_neighborhood = (
#       8     pogoh_data.groupby('Neighborhood')['Total Docks']
#       9     .sum()
#      10     .reset_index(name='Total Docks')
#      11 )
#
# File /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Neighborhood'

# %% [markdown]
# We display a bar chart that gives us an idea of which neighborhood has the most POGOH docks per neighborhood

# %%
plt.figure(figsize=(12, 6))
dock_counts_df.set_index('Neighborhood')['Total Number of Docks'] \
    .sort_values(ascending=False) \
    .plot(kind='bar')

plt.xlabel("Neighborhood")
plt.ylabel("Total Number of Docks")
plt.title("Number of Bike docks in Neighborhood")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Based on the POGOH dock analysis, **Central Oakland** has the highest total number of bike docks in Pittsburgh, while **North Oakland** ranks third in overall dock count. When examining dock density, however, **Terrace Village** stands out with the highest concentration of docks, followed by North Oakland in fourth and Central Oakland in fifth place. Considering both total docks and dock density together, **North Oakland** emerges as the strongest overall neighborhood, offering both a high number of docks and a relatively high density, making it the most well-balanced and accessible area for bike-share users.
